# %% [markdown]
# <a href="https://colab.research.google.com/github/RaiyanMohiuddin104/Data-Science-Programs/blob/main/Week-4/DatabaseOperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
conn=sqlite3.connect("example.db")
cursor=conn.cursor()
cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    age INTEGER,
    email TEXT UNIQUE
)
""")
print("Table created successfully.")
cursor.execute("INSERT INTO users(name, age, email) VALUES('Raiyan Mohiuddin',22,'raiyanmohiuddin@gmail.com')")
cursor.execute("INSERT INTO users(name, age, email) VALUES('Neha',24,'neha230406@gmail.com')")
conn.commit()
print("Data inserted successfully.")
cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()
print("\nUsers in database:")
for row in rows:
    print(row)
cursor.execute("UPDATE users SET age = 25 WHERE name = 'Raiyan'")
conn.commit()
print("\nRecord updated successfully.")
cursor.execute("DELETE FROM users WHERE name = 'Neha'")
conn.commit()
print("Record deleted successfully.")
cursor.execute("SELECT * FROM users")
rows=cursor.fetchall()
print("\nFinal data:")
for row in rows:
    print(row)
conn.close()
print("\nDatabase connection closed.")
# Out:
# Table created successfully.
# Data inserted successfully.
#
# Users in database:
# (1, 'Raiyan Mohiuddin', 22, 'raiyanmohiuddin@gmail.com')
# (2, 'Neha', 24, 'neha230406@gmail.com')
#
# Record updated successfully.
# Record deleted successfully.
#
# Final data:
# (1, 'Raiyan Mohiuddin', 22, 'raiyanmohiuddin@gmail.com')
#
# Database connection closed.
