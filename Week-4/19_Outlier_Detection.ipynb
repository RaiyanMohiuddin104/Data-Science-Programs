# %% [markdown]
# <a href="https://colab.research.google.com/github/RaiyanMohiuddin104/Data-Science-Programs/blob/main/Week-4/19_Outlier_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 19)Write the python code to detect the outliers
#
# Date:- 24/2/26

# %%
import pandas as pd
data={'Name':['Aryan','Beena','Chetan','David','Emily'],
      'Age':[13,24,25,29,95]
      }
df=pd.DataFrame(data)
Q1=df['Age'].quantile(0.25)
Q3=df['Age'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
outliers=df[(df['Age'] > upper_bound)]
print("Outliers using IQR method:")
print(outliers)
# Out:
# Outliers using IQR method:
#     Name  Age
# 4  Emily   95
