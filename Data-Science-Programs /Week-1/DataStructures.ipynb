# %% [markdown]
# <a href="https://colab.research.google.com/github/RaiyanMohiuddin104/Data-Science-Programs/blob/main/Data-Science-Programs%20/Week-1/DataStructures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2.Write a code to implement the following data structures
#a) List
#a) Tuples
#a) Dictionaries
#a) Set
ls = [10,20,30,40,50]
tu = (2,4,6,8,10,12,14)
dic = {
    "Name":"Raiyan",
    "Age" : 20,
    "Gender" : "Male",
}
st = {100,200,300,400,500}
print("List:- ",ls)
print("Tuples:- ",tu)
print("Dictionary:- ",dic)
print("Set:- ",st)
# Out:
# List:-  [10, 20, 30, 40, 50]
# Tuples:-  (2, 4, 6, 8, 10, 12, 14)
# Dictionary:-  {'Name': 'Raiyan', 'Age': 20, 'Gender': 'Male'}
# Set:-  {400, 100, 500, 200, 300}
