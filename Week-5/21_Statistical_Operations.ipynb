# %% [markdown]
# <a href="https://colab.research.google.com/github/RaiyanMohiuddin104/Data-Science-Programs/blob/main/Week-5/21_Statistical_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q.21)Write the code to perform the following operations
#
# a)Z-score
#
# b)Statistical inference
#
# c)random variable model
#
# d)Central limit theorem
#
# e)standardizations
#
# Date:- 10-03-2026

# %%
#Z-score
import numpy as np
data=[5,10,15,25,35,45,55]
mean=np.mean(data)
print("Mean:",mean)
std_dev=np.std(data,ddof=0)
print("Standard Deviation:",std_dev)
x=40
z_score=(x-mean)/std_dev
print("Z-score:",z_score)
z_scores=[(x-mean)/std_dev for x in data]
print("Z-scores:",z_scores)
# Out:
# Mean: 27.142857142857142
# Standard Deviation: 17.29102633844315
# Z-score: 0.7435731462948248
# Z-scores: [np.float64(-1.2805981963966426), np.float64(-0.991430861726433), np.float64(-0.7022635270562234), np.float64(-0.12392885771580411), np.float64(0.4544058116246152), np.float64(1.0327404809650345), np.float64(1.611075150305454)]

# %%
#Statistical inference--random variable model, central limit theorem and standardization
import numpy as np
import math
import matplotlib.pyplot as plt
population=np.array([5,10,15,20,25,30,35,40,35,50])
N=len(population)
print("Population Size(N):",N)
mu=np.mean(population)
print("Populaytion mean:",mu)
sigma2=np.var(population,ddof=0)
print("Population variance:",sigma2)
sigma=math.sqrt(sigma2)
print("Population standard deviation:",sigma)
sample=np.array([20,30,40,50])
n=len(sample)
print("Sample Size(n):",n)
x_bar=np.mean(sample)
print("Sample mean:",x_bar)
s2=np.var(sample,ddof=0)
print("Sample variance:",s2)
s=math.sqrt(s2)
print("Sample standard deviation:",s)
SE=sigma/math.sqrt(n)
print("Standard Error:",SE)
z=(x_bar-mu)/SE
print("Z-score:",z)
num_samples = 1000
sample_size = 4
sample_means = []
for i in range(num_samples):
    samp=np.random.choice(population, sample_size, replace=True)
    sample_means.append(np.mean(samp))
sample_means=np.array(sample_means)
print("Mean of sample means:",np.mean(sample_means))
print("Std of sample means:",np.std(sample_means))
plt.hist(sample_means, bins=20,edgecolor='black')
plt.title("Central Limit Theorem: Distribution of Sample Means")
plt.xlabel("Sample Mean")
plt.ylabel("Frequency")
plt.show()
# Out:
# Population Size(N): 10
# Populaytion mean: 26.5
# Population variance: 180.25
# Population standard deviation: 13.425721582097552
# Sample Size(n): 4
# Sample mean: 35.0
# Sample variance: 125.0
# Sample standard deviation: 11.180339887498949
# Standard Error: 6.712860791048776
# Z-score: 1.2662261686305598
# Mean of sample means: 26.23
# Std of sample means: 6.867239256062075
