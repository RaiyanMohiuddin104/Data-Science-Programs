# %% [markdown]
# <a href="https://colab.research.google.com/github/RaiyanMohiuddin104/Data-Science-Programs/blob/main/Week-5/22_Hypothesis_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q.22)Write a code to test the hypothesis, if test for Z is accepted or rejected
#
# Date:- 10-03-2026

# %%
#test for hypothesis code
import math
n=150
x=80
p_hat=x/n
SE=math.sqrt(p_hat*(1-p_hat)/n)
z=1.96
lower=p_hat-z*SE
upper=p_hat+z*SE
print("Sample proportion:",p_hat)
print("Confidence Interval:",(lower,upper))
p0=0.50
z_test=(p_hat-p0)/math.sqrt(p0*(1-p0)/n)
print("Test Statistic:",z_test)
if abs(z_test)>1.96:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# Sample proportion: 0.5333333333333333
# Confidence Interval: (0.4534946812256583, 0.6131719854410084)
# Test Statistic: 0.8164965809277258
# Accept null hypothesis
