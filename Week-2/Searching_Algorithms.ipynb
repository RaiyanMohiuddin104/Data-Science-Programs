# %% [markdown]
# <a href="https://colab.research.google.com/github/RaiyanMohiuddin104/Data-Science-Programs/blob/main/Week-2/Searching_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def linear_search(arr,target):
  for i in range(len(arr)):
    if arr[i] == target:
      return i
  return -1
arr = list(map(int, input("Enter elements separated by space: ").split()))
target = int(input("Enter the target:- "))
result = linear_search(arr,target)
if result!= -1:
  print(f"{target} found at index {result}")
else:
  print(f"{target} not found")
# Out:
# Enter elements separated by space: 10 20 30 40 50
# Enter the target:- 30
# 30 found at index 2

# %%
#B.Binary Search
def binary_search(arr,target):
  left = 0
  right = len(arr) - 1
  while left<= right:
    mid = (left+right)//2
    if arr[mid] == target:
      return mid
    elif arr[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return -1
arr = list(map(int, input("Enter sorted elements separated by space: ").split()))
target = int(input("Enter the element to be searched:- "))
result = binary_search(arr,target)
if result != -1:
  print(f"{target} is found at index {result}")
else:
  print(f"{target} not found")
# Out:
# Enter sorted elements separated by space: 11 12 23 89 76 45
# Enter the element to be searched:- 11
# 11 is found at index 0
