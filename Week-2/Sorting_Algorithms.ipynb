# %% [markdown]
# <a href="https://colab.research.google.com/github/RaiyanMohiuddin104/Data-Science-Programs/blob/main/Week-2/Sorting_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#6.Write the code to implement the following sorting algorithms
#a) Bubble Sort
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

arr = list(map(int, input("Enter numbers: ").split()))
result = bubble_sort(arr)
print("Sorted array:", result)
# Out:
# Enter numbers: 10 12 22 3 55 79
# Sorted array: [3, 10, 12, 22, 55, 79]

# %%
#b) Selection Sort
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i+1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr
arr = list(map(int, input("Enter numbers: ").split()))
result = selection_sort(arr)
print("Sorted array:",result)
# Out:
# Enter numbers: 34 23 10 3 45 67 88 90
# Sorted array: [3, 10, 23, 34, 45, 67, 88, 90]

# %%
#c) Insertion Sort
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr
arr = list(map(int, input("Enter numbers: ").split()))
result = insertion_sort(arr)
print("Sorted array:",result)
# Out:
# Enter numbers: 10 20 300 12 45 2
# Sorted array: [2, 10, 12, 20, 45, 300]
